# %%
#loading Packages and gaining earthaccess
import earthaccess
import xarray as xr
from xarray.backends.api import open_datatree
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import pandas as pd

auth = earthaccess.login(persist=True)
print('loaded')
# Out:
# loaded

# %%
input_date = "2024-06-22"

def main():
    date_list = ["2024-06-22"] ###EDIT 
    for date_curr in date_list:

def file_scraper(input_date)
    tspan = (input_date, input_date)
    results = earthaccess.search_data(
        short_name="PACE_OCI_L3M_KD_NRT",
        temporal=tspan,
        granule_name="*.DAY.*.0p1deg.*",
    )
    paths = earthaccess.open(results)
    if len(paths == 0)
        print('no available path data for:', date_curr)
    datatree = open_datatree(paths[0])
# Out:
# Granules found: 1
# Opening 1 granules, approx size: 0.01 GB
# using endpoint: https://obdaac-tea.earthdatacloud.nasa.gov/s3credentials
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# <class 'list'>

# %%
dataset = xr.merge(datatree.to_dict().values())
dataset
# Out:
# <xarray.Dataset> Size: 441MB
# Dimensions:     (wavelength: 17, lat: 1800, lon: 3600, rgb: 3,
#                  eightbitcolor: 256)
# Coordinates:
#   * wavelength  (wavelength) float64 136B 351.0 361.0 385.0 ... 678.0 711.0
#   * lat         (lat) float32 7kB 89.95 89.85 89.75 ... -89.75 -89.85 -89.95
#   * lon         (lon) float32 14kB -179.9 -179.9 -179.8 ... 179.8 179.9 180.0
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     Kd          (lat, lon, wavelength) float32 441MB ...
#     palette     (rgb, eightbitcolor) uint8 768B ...
# Attributes: (12/64)
#     product_name:                      PACE_OCI.20240622.L3m.DAY.KD.V2_0.Kd.0...
#     instrument:                        OCI
#     title:                             OCI Level-3 Standard Mapped Image
#     project:                           Ocean Biology Processing Group (NASA/G...
#     platform:                          PACE
# ...

# %%
kd = dataset["Kd"]
kd_np = xr.DataArray.to_numpy(kd)
kd_subset = kd_np[500, 500, :]
print(kd_subset)
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
